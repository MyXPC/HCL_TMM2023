# %%
import torch

a,b,c,d=2,3,9,7
saliency_figure = torch.randn((3, 448, 448))
print(saliency_figure.shape)
show = saliency_figure[:,32*b:32*(b+d),32*a:32*(a+c)]
print(saliency_figure[:,32*b:32*(b+d),32*a:32*(a+c)].shape,a,b,c,d)
# Out:
# torch.Size([3, 448, 448])
# torch.Size([3, 224, 288]) 2 3 9 7
